# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# #Generate / Load Data

# %%
np.random.seed(42)

n = 1000

data = {
    "OrderID": np.arange(1000, 1000 + n),
    "OrderDate": pd.date_range(start="2023-01-01", periods=n, freq="D"),
    "Region": np.random.choice(["North", "South", "East", "West"], n),
    "Category": np.random.choice(["Technology", "Furniture", "Office Supplies"], n),
    "Product": np.random.choice(
        ["Laptop", "Phone", "Chair", "Table", "Pen", "Notebook", "Tablet"], n
    ),
    "Sales": np.random.randint(20, 2000, n),
    "Quantity": np.random.randint(1, 10, n),
}

df = pd.DataFrame(data)

df["Profit"] = (df["Sales"] * np.random.uniform(0.1, 0.3, n)).round(2)
df["CustomerSegment"] = np.random.choice(
    ["Consumer", "Corporate", "Home Office"], n
)

df["OrderDate"] = pd.to_datetime(df["OrderDate"])

df.head()
# Out:
#    OrderID  OrderDate Region         Category Product  Sales  Quantity  \
# 0     1000 2023-01-01   East        Furniture   Table   1216         9
# 1     1001 2023-01-02   West  Office Supplies     Pen   1999         7
# 2     1002 2023-01-03  North       Technology     Pen   1055         9
# 3     1003 2023-01-04   East       Technology  Laptop   1843         3
# 4     1004 2023-01-05   East       Technology   Phone    147         4
#
#    Profit CustomerSegment
# 0  249.46       Corporate
# 1  299.66       Corporate
# 2  105.93        Consumer
# 3  248.47       Corporate
# 4   18.14       Corporate

# %% [markdown]
# #KPI Metrics (Dashboard Style)

# %%
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
total_orders = df["OrderID"].nunique()
avg_order_value = total_sales / total_orders

print("📊 KPI SUMMARY")
print(f"Total Sales: ${total_sales:,.0f}")
print(f"Total Profit: ${total_profit:,.0f}")
print(f"Total Orders: {total_orders}")
print(f"Avg Order Value: ${avg_order_value:,.2f}")
# Out:
# 📊 KPI SUMMARY
# Total Sales: $1,006,565
# Total Profit: $200,796
# Total Orders: 1000
# Avg Order Value: $1,006.57

# %% [markdown]
# #Sales Trend

# %%
trend = df.groupby("OrderDate")["Sales"].sum().reset_index()

fig = px.line(
    trend,
    x="OrderDate",
    y="Sales",
    title="📈 Sales Trend Over Time"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Sales by Region

# %%
region_sales = df.groupby("Region")["Sales"].sum().reset_index()

fig = px.bar(
    region_sales,
    x="Region",
    y="Sales",
    color="Region",
    title="🌍 Sales by Region"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Category Distribution

# %%
category_sales = df.groupby("Category")["Sales"].sum().reset_index()

fig = px.pie(
    category_sales,
    names="Category",
    values="Sales",
    hole=0.4,
    title="📦 Sales by Category"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Top Products

# %%
top_products = (
    df.groupby("Product")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

fig = px.bar(
    top_products,
    x="Product",
    y="Sales",
    color="Product",
    title="🏆 Top Products"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Customer Segment Analysis

# %%
segment = df.groupby("CustomerSegment")["Sales"].sum().reset_index()

fig = px.bar(
    segment,
    x="CustomerSegment",
    y="Sales",
    color="CustomerSegment",
    title="👥 Customer Segment Analysis"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Advanced: Monthly Sales Trend

# %%
df["Month"] = df["OrderDate"].dt.to_period("M").astype(str)

monthly_sales = df.groupby("Month")["Sales"].sum().reset_index()

fig = px.line(
    monthly_sales,
    x="Month",
    y="Sales",
    markers=True,
    title="📅 Monthly Sales Trend"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Insights

# %%
print("📊 BUSINESS INSIGHTS\n")

print(f"✅ Best Region: {region_sales.loc[region_sales['Sales'].idxmax(), 'Region']}")
print(f"✅ Best Category: {category_sales.loc[category_sales['Sales'].idxmax(), 'Category']}")
print(f"✅ Top Product: {top_products.loc[0, 'Product']}")
print(f"✅ Best Segment: {segment.loc[segment['Sales'].idxmax(), 'CustomerSegment']}")
# Out:
# 📊 BUSINESS INSIGHTS
#
# ✅ Best Region: West
# ✅ Best Category: Technology
# ✅ Top Product: Phone
# ✅ Best Segment: Home Office

# %% [markdown]
# #Save Dataset

# %%
df.to_csv("sales_data.csv", index=False)
print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully
